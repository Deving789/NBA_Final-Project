# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
# %matplotlib inline

import csv
df = pd.read_csv("/Users/brianahn/nba_location_stats_2014-15.csv")
df
# Out:
#          Game ID  Game Event ID  Player ID   Player Name     Team ID  \
# 0       21400014             44     101106  Andrew Bogut  1610612744
# 1       21400014            336     101106  Andrew Bogut  1610612744
# 2       21400038              2     101106  Andrew Bogut  1610612744
# 3       21400038             25     101106  Andrew Bogut  1610612744
# 4       21400038             53     101106  Andrew Bogut  1610612744
# ...          ...            ...        ...           ...         ...
# 205545  21400632            323        977   Kobe Bryant  1610612747
# 205546  21400632            332        977   Kobe Bryant  1610612747
# 205547  21400632            334        977   Kobe Bryant  1610612747
# 205548  21400632            469        977   Kobe Bryant  1610612747
# 205549  21400632            474        977   Kobe Bryant  1610612747
#
#                     Team Name  Period  Minutes Remaining  Seconds Remaining  \
# ...

# %%
import csv
df2 = pd.read_csv("/Users/brianahn/sportsref_download.csv")
df2
# Out:
#       Rk                     Team   Age     W     L  PW  PL    MOV   SOS  \
# 0    1.0   Golden State Warriors*  26.6  67.0  15.0  65  17  10.10 -0.09
# 1    2.0    Los Angeles Clippers*  28.8  56.0  26.0  58  24   6.59  0.22
# 2    3.0       San Antonio Spurs*  29.8  55.0  27.0  58  24   6.20  0.14
# 3    4.0           Atlanta Hawks*  27.8  60.0  22.0  56  26   5.43 -0.68
# 4    5.0  Portland Trail Blazers*  27.0  51.0  31.0  53  29   4.23  0.18
# 5    6.0     Cleveland Cavaliers*  26.9  53.0  29.0  53  29   4.48 -0.40
# 6    7.0         Houston Rockets*  27.6  56.0  26.0  50  32   3.44  0.38
# 7    8.0       Memphis Grizzlies*  29.6  55.0  27.0  50  32   3.24  0.38
# 8    9.0        Dallas Mavericks*  29.9  50.0  32.0  49  33   2.90  0.46
# 9   10.0           Chicago Bulls*  28.8  50.0  32.0  50  32   3.00 -0.46
# 10  11.0    Oklahoma City Thunder  25.4  45.0  37.0  47  35   2.18  0.28
# 11  12.0         Toronto Raptors*  26.1  49.0  33.0  49  33   3.07 -0.62
# ...

# %%
df2.drop(["W","L"], axis=1)
df2
# Out:
#       Rk                     Team   Age     W     L  PW  PL    MOV   SOS  \
# 0    1.0   Golden State Warriors*  26.6  67.0  15.0  65  17  10.10 -0.09
# 1    2.0    Los Angeles Clippers*  28.8  56.0  26.0  58  24   6.59  0.22
# 2    3.0       San Antonio Spurs*  29.8  55.0  27.0  58  24   6.20  0.14
# 3    4.0           Atlanta Hawks*  27.8  60.0  22.0  56  26   5.43 -0.68
# 4    5.0  Portland Trail Blazers*  27.0  51.0  31.0  53  29   4.23  0.18
# 5    6.0     Cleveland Cavaliers*  26.9  53.0  29.0  53  29   4.48 -0.40
# 6    7.0         Houston Rockets*  27.6  56.0  26.0  50  32   3.44  0.38
# 7    8.0       Memphis Grizzlies*  29.6  55.0  27.0  50  32   3.24  0.38
# 8    9.0        Dallas Mavericks*  29.9  50.0  32.0  49  33   2.90  0.46
# 9   10.0           Chicago Bulls*  28.8  50.0  32.0  50  32   3.00 -0.46
# 10  11.0    Oklahoma City Thunder  25.4  45.0  37.0  47  35   2.18  0.28
# 11  12.0         Toronto Raptors*  26.1  49.0  33.0  49  33   3.07 -0.62
# ...
