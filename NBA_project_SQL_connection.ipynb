# %% [markdown]
# # Import working files to Pandas

# %% [markdown]
# ## Import shot_log and player_stats

# %%
#import dependencies
import json
import pandas as pd
import numpy as np
from pandas import DataFrame
import matplotlib.pylab as plt
import matplotlib.pyplot as plt
#import seaborn as sns

# %%
# add import warnigns to skip any warning messages on the screen
import warnings
warnings.filterwarnings('ignore')

# %%
#create file direcotry
file_dir = 'C:/Users/larys/DAB/Final_Project/Resources/'

# %%
#import the csv files
shot_log = pd.read_csv(f'{file_dir}shot_logs.csv', index_col=0)
stats = pd.read_csv(f'{file_dir}players_stats2.csv', index_col=0)

# %% [markdown]
# ### Check first dataset - shot_logs

# %%
# check shot_log data
# check all column in the dataset
shot_log.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128069 entries, 21400899 to 21400006
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   MATCHUP                     128069 non-null  object
#  1   LOCATION                    128069 non-null  object
#  2   W                           128069 non-null  object
#  3   FINAL_MARGIN                128069 non-null  int64
#  4   SHOT_NUMBER                 128069 non-null  int64
#  5   PERIOD                      128069 non-null  int64
#  6   GAME_CLOCK                  128069 non-null  object
#  7   SHOT_CLOCK                  122502 non-null  float64
#  8   DRIBBLES                    128069 non-null  int64
#  9   TOUCH_TIME                  128069 non-null  float64
#  10  SHOT_DIST                   128069 non-null  float64
#  11  PTS_TYPE                    128069 non-null  int64
# ...

# %% [markdown]
# ### Explore the second dataset - players_stats

# %%
# check stats file for data types
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 490 entries, AJ Price to Zoran Dragic
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Games_Played  490 non-null    int64
#  1   MIN           490 non-null    int64
#  2   PTS           490 non-null    int64
#  3   FGM           490 non-null    int64
#  4   FGA           490 non-null    int64
#  5   FGPrct        490 non-null    float64
#  6   3PM           490 non-null    int64
#  7   3PA           490 non-null    int64
#  8   3Prct         490 non-null    float64
#  9   FTM           490 non-null    int64
#  10  FTA           490 non-null    int64
#  11  FTPrct        490 non-null    float64
#  12  OREB          490 non-null    int64
#  13  DREB          490 non-null    int64
#  14  REB           490 non-null    int64
#  15  AST           490 non-null    int64
#  16  STL           490 non-null    int64
#  17  BLK           490 non-null    int64
# ...

# %% [markdown]
# ## Adding additional dataset with nba historical (nba_historical)

# %%
#import the csv files
nba_historical = pd.read_csv(f'{file_dir}NBA Shot Locations 1997 - 2020.csv', index_col=0)

# %%
print(nba_historical.shape)
nba_historical.head()
# Out:
# (4729512, 21)
#           Game Event ID  Player ID Player Name     Team ID  \
# Game ID
# 29700427            389        100  Tim Legler  1610612764
# 29700427            406        100  Tim Legler  1610612764
# 29700427            475        100  Tim Legler  1610612764
# 29700427            487        100  Tim Legler  1610612764
# 29700427            497        100  Tim Legler  1610612764
#
#                    Team Name  Period  Minutes Remaining  Seconds Remaining  \
# Game ID
# 29700427  Washington Wizards       4                 11                 22
# 29700427  Washington Wizards       4                  9                 36
# 29700427  Washington Wizards       4                  3                  7
# 29700427  Washington Wizards       4                  1                 45
# 29700427  Washington Wizards       4                  0                 45
#
#          Action Type       Shot Type  ... Shot Zone Area  Shot Zone Range  \
# Game ID                               ...
# ...

# %%
nba_historical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4729512 entries, 29700427 to 41800406
# Data columns (total 21 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Game Event ID      int64
#  1   Player ID          int64
#  2   Player Name        object
#  3   Team ID            int64
#  4   Team Name          object
#  5   Period             int64
#  6   Minutes Remaining  int64
#  7   Seconds Remaining  int64
#  8   Action Type        object
#  9   Shot Type          object
#  10  Shot Zone Basic    object
#  11  Shot Zone Area     object
#  12  Shot Zone Range    object
#  13  Shot Distance      int64
#  14  X Location         int64
#  15  Y Location         int64
#  16  Shot Made Flag     int64
#  17  Game Date          int64
#  18  Home Team          object
#  19  Away Team          object
#  20  Season Type        object
# dtypes: int64(11), object(10)
# memory usage: 793.8+ MB

# %%
 # # create a list of our conditions
nba_seasons = [
    # 1997-1998 Regular Season: October 31, 1997 – April 19, 1998
    # 1998 NBA Playoffs: April 23 – May 31, 1998
    # 1998 NBA Finals:June 3 – 14, 1998
    (nba_historical['Game Date'].between(19971001, 19980419)),
    (nba_historical['Game Date'].between(19980423, 19980531)),
    (nba_historical['Game Date'].between(19980603, 19980614)),
    
    # 1998-1999 Regular Season: February 5 – May 5, 1999
    # 1999 Playoffs: May 8 – June 11, 1999
    # 1999 NBA Finals: June 16 – 25, 1999
    (nba_historical['Game Date'].between(19990205, 19990505)),
    (nba_historical['Game Date'].between(19990508, 19990611)),
    (nba_historical['Game Date'].between(19990612, 19990625)),
    
    # 1999-2000 Regular Season: November 2, 1999 – April 19, 2000
    # 2000 Playoffs: April 22 – June 4, 2000
    # 2000 Finals: June 7 – 19, 2000
    (nba_historical['Game Date'].between(19991102, 20000419)),
    (nba_historical['Game Date'].between(20000422, 20000604)),
    (nba_historical['Game Date'].between(20000607, 20000619)),
    
    # 2000-2001 Regular Season: October 31, 2000 – April 18, 2001
    # 2001 Playoffs: April 21 – June 3, 2001
    # 2001 Finals: June 6 – 15, 2001
    (nba_historical['Game Date'].between(20001031, 20010418)),
    (nba_historical['Game Date'].between(20010420, 20010604)),
    (nba_historical['Game Date'].between(20010606, 20010615)),    
    
    # 2001-02 Regular Season: October 30, 2001 – April 17, 2002
    # 2002 Playoffs: April 20 – June 2, 2002
    # 2002 Finals: June 5 – 12, 2002 
    (nba_historical['Game Date'].between(20011031, 20020418)),
    (nba_historical['Game Date'].between(20020420, 20020604)),
    (nba_historical['Game Date'].between(20020605, 20020615)),   
       
    # 2002-03 Regular Season: October 29, 2002 – April 16, 2003
    # 2003 Playoffs: April 19 – May 29, 2003
    # 2003 Finals: June 4 – 15, 2003
    (nba_historical['Game Date'].between(20021029, 20030416)),
    (nba_historical['Game Date'].between(20030419, 20030529)),
    (nba_historical['Game Date'].between(20030603, 20030615)),     
    
    # 2003-04 Regular Season: October 28, 2003 – April 14, 2004
    # 2004 Playoffs: April 17 – June 1, 2004
    # 2004 Finals: June 6 – 15, 2004 
    (nba_historical['Game Date'].between(20031028, 20040416)),
    (nba_historical['Game Date'].between(20040417, 20040601)),
    (nba_historical['Game Date'].between(20040606, 20040615)),     
    
    # 2004-05 Regular Season: November 2, 2004 – April 20, 2005
    # 2005 Playoffs: April 23 – June 6, 2005
    # 2005 Finals: June 9–23, 2005
    (nba_historical['Game Date'].between(20041102, 20050420)),
    (nba_historical['Game Date'].between(20050423, 20050602)),
    (nba_historical['Game Date'].between(20050609, 20050623)), 
        
    # 2005-06 Regular Season: November 1, 2005 – April 19, 2006
    # 2006 Playoffs: April 22 – June 3, 2006
    # 2006 Finals: June 8 – 20, 2006
    (nba_historical['Game Date'].between(20051101, 20060419)),
    (nba_historical['Game Date'].between(20060422, 20060603)),
    (nba_historical['Game Date'].between(20060608, 20060620)),
        
    # 2006-07 Regular Season: October 31, 2006 – April 18, 2007
    # 2007 Playoffs: April 21 – June 2, 2007
    # 2007 Finals: June 7 – 14, 2007 
    (nba_historical['Game Date'].between(20061031, 20070418)),
    (nba_historical['Game Date'].between(20070421, 20070603)),
    (nba_historical['Game Date'].between(20070607, 20070620)),        
        
    # 2007-08 Regular Season: October 30, 2007 – April 16, 2008
    # 2008 Playoffs: April 19 – May 30, 2008
    # 2008 Finals: June 5 – 17, 2008
    (nba_historical['Game Date'].between(20071030, 20080416)),
    (nba_historical['Game Date'].between(20080419, 20080603)),
    (nba_historical['Game Date'].between(20080605, 20080617)),          
        
    # 2008-09 Regular Season: October 28, 2008 – April 16, 2009
    # 2009 Playoffs: April 18 – May 30, 2009
    # 2009 Finals: June 4 – 14, 2009
    (nba_historical['Game Date'].between(20081028, 20090416)),
    (nba_historical['Game Date'].between(20090417, 20090603)),
    (nba_historical['Game Date'].between(20090604, 20090617)),                
            
    # 2009-10 Regular Season: October 27, 2009 – April 14, 2010
    # 2010 Playoffs: April 17 – May 29, 2010
    # 2010 Finals: June 3 – 17, 2010 
    (nba_historical['Game Date'].between(20091027, 20100416)),
    (nba_historical['Game Date'].between(20100417, 20100529)),
    (nba_historical['Game Date'].between(20100603, 20100617)),                 
    
    # 2010-11 Regular Season: October 26, 2010 – April 13, 2011
    # 2011 Playoffs: April 16 – May 26, 2011
    # 2011 Finals: May 31 – June 12, 2011
    (nba_historical['Game Date'].between(20101026, 20110416)),
    (nba_historical['Game Date'].between(20110416, 20110526)),
    (nba_historical['Game Date'].between(20110531, 20110617)),      
    
    # 2011-12 Regular Season: December 25, 2011 – April 26, 2012
    # 2012 Playoffs: April 28 – June 9, 2012
    # 2012 Finals: June 12 – 21, 2012
    (nba_historical['Game Date'].between(20111224, 20120426)),
    (nba_historical['Game Date'].between(20120428, 20120609)),
    (nba_historical['Game Date'].between(20120612, 20120621)),              
    
    # 2012-13 Regular Season: October 30, 2012 – April 17, 2013
    # 2013 Playoffs: April 20 – June 3, 2013
    # 2013 Finals: June 6 – 20, 2013  
    (nba_historical['Game Date'].between(20121026, 20130417)),
    (nba_historical['Game Date'].between(20130420, 20130603)),
    (nba_historical['Game Date'].between(20130606, 20130620)),      
    
    # 2013-14 Regular Season: October 29, 2013 – April 16, 2014
    # 2014 Playoffs: April 19, 2014 – May 31, 2014
    # 2014 Finals: June 5 – 15, 2014
    (nba_historical['Game Date'].between(20131026, 20140416)),
    (nba_historical['Game Date'].between(20140419, 20140531)),
    (nba_historical['Game Date'].between(20140605, 20140620)),       
      
    # 2014-15 Regular Season: October 28, 2014 – April 15, 2015
    # 2015 Playoffs: April 18, 2015 – May 27, 2015
    # 2015 Finals: June 4, 2015 – June 16, 2015
    (nba_historical['Game Date'].between(20141026, 20150415)),
    (nba_historical['Game Date'].between(20150418, 20150527)),
    (nba_historical['Game Date'].between(20150604, 20150616)),      
    
    # 2015-16 Regular Season: October 27, 2015 – April 13, 2016 
    # 2016 Playoffs: April 16, 2016 – May 30, 2016
    # 2016 Finals: June 2, 2016 – June 19, 2016
    (nba_historical['Game Date'].between(20151026, 20160415)),
    (nba_historical['Game Date'].between(20160416, 20160530)),
    (nba_historical['Game Date'].between(20160602, 20160619)),      
    
    # 2016-17 Regular Season: October 25, 2016 – April 12, 2017
    # 2017 Playoffs: April 15 – May 25, 2017
    # 2017 Finals: June 1–12, 2017
    (nba_historical['Game Date'].between(20161025, 20170412)),
    (nba_historical['Game Date'].between(20170414, 20170530)),
    (nba_historical['Game Date'].between(20170601, 20170619)),          
    
    # 2017-18 Regular Season: October 17, 2017 – April 11, 2018
    # 2018 Playoffs: April 14 – May 28, 2018
    # 2018 Finals: May 31 – June 8, 2018
    (nba_historical['Game Date'].between(20171017, 20180412)),
    (nba_historical['Game Date'].between(20180414, 20180530)),
    (nba_historical['Game Date'].between(20180531, 20180619)),         
    
    # 2018-19 Regular Season: October 16, 2018 – April 10, 2019
    # 2019 Playoffs: April 13 – May 25, 2019
    # 2019 Finals: May 30 – June 13, 2019 
    (nba_historical['Game Date'].between(20181016, 20190412)),
    (nba_historical['Game Date'].between(20190414, 20190529)),
    (nba_historical['Game Date'].between(20190531, 20190619)),       
    
    # 2019-20 Regular Season: COVID impact
    # October 22, 2019 – March 11, 2020 (regular season before suspension)
    # July 30 – August 14, 2020 (completion of regular season with "seeding" games)
    # August 15, 2020 (Play-in tournament)
    # 2020 Playoffs: August 17 – September 27, 2020
    # 2020 Finals: September 30 – October 11, 2020
    (nba_historical['Game Date'].between(20191016, 20200816)),
    (nba_historical['Game Date'].between(20200817, 20200928)),
    (nba_historical['Game Date'].between(20190929, 20201012))    
    ]

# # create a list of the values we want to assign for each condition
values = ['1997-98 NBA Season', '1998 NBA Playoffs', '1998 NBA Finals', \
          '1998-99 NBA Season', '1999 NBA Playoffs', '1999 NBA Finals', \
          '1999-2000 NBA Season', '2000 NBA Playoffs', '2000 NBA Finals', \
          '2000-01 NBA Season', '2001 NBA Playoffs', '2001 NBA Finals', \
          '2001-02 NBA Season', '2002 NBA Playoffs', '2002 NBA Finals', \
          '2002-03 NBA Season', '2003 NBA Playoffs', '2003 NBA Finals', \
          '2003-04 NBA Season', '2004 NBA Playoffs', '2004 NBA Finals', \
          '2004-05 NBA Season', '2005 NBA Playoffs', '2005 NBA Finals', \
          '2005-06 NBA Season', '2006 NBA Playoffs', '2006 NBA Finals', \
          '2006-07 NBA Season', '2007 NBA Playoffs', '2007 NBA Finals', \
          '2007-08 NBA Season', '2008 NBA Playoffs', '2008 NBA Finals', \
          '2008-09 NBA Season', '2009 NBA Playoffs', '2009 NBA Finals', \
          '2009-10 NBA Season', '2010 NBA Playoffs', '2010 NBA Finals', \
          '2010-11 NBA Season', '2011 NBA Playoffs', '2011 NBA Finals', \
          '2011-12 NBA Season', '2012 NBA Playoffs', '2012 NBA Finals', \
          '2012-13 NBA Season', '2013 NBA Playoffs', '2013 NBA Finals', \
          '2013-14 NBA Season', '2014 NBA Playoffs', '2014 NBA Finals', \
          '2014-15 NBA Season', '2015 NBA Playoffs', '2015 NBA Finals', \
          '2015-16 NBA Season', '2016 NBA Playoffs', '2016 NBA Finals', \
          '2016-17 NBA Season', '2017 NBA Playoffs', '2017 NBA Finals', \
          '2017-18 NBA Season', '2018 NBA Playoffs', '2018 NBA Finals', \
          '2018-19 NBA Season', '2019 NBA Playoffs', '2019 NBA Finals', \
          '2019-20 NBA Season', '2020 NBA Playoffs', '2020 NBA Finals'
         ]


# # create a new column and use np.select to assign values to it using our lists as arguments
nba_historical['Season'] = np.select(nba_seasons, values)


# # display updated DataFrame
nba_historical.head()
# Out:
#           Game Event ID  Player ID Player Name     Team ID  \
# Game ID
# 29700427            389        100  Tim Legler  1610612764
# 29700427            406        100  Tim Legler  1610612764
# 29700427            475        100  Tim Legler  1610612764
# 29700427            487        100  Tim Legler  1610612764
# 29700427            497        100  Tim Legler  1610612764
#
#                    Team Name  Period  Minutes Remaining  Seconds Remaining  \
# Game ID
# 29700427  Washington Wizards       4                 11                 22
# 29700427  Washington Wizards       4                  9                 36
# 29700427  Washington Wizards       4                  3                  7
# 29700427  Washington Wizards       4                  1                 45
# 29700427  Washington Wizards       4                  0                 45
#
#          Action Type       Shot Type  ...  Shot Zone Range Shot Distance  \
# Game ID                               ...
# ...

# %%
nba_historical.tail()
# Out:
#           Game Event ID  Player ID     Player Name     Team ID  \
# Game ID
# 41800406            366       2738  Andre Iguodala  1610612744
# 41800406            392       2738  Andre Iguodala  1610612744
# 41800406            404       2738  Andre Iguodala  1610612744
# 41800406            468       2738  Andre Iguodala  1610612744
# 41800406            584       2738  Andre Iguodala  1610612744
#
#                       Team Name  Period  Minutes Remaining  Seconds Remaining  \
# Game ID
# 41800406  Golden State Warriors       3                  7                 51
# 41800406  Golden State Warriors       3                  6                  8
# 41800406  Golden State Warriors       3                  4                 41
# 41800406  Golden State Warriors       3                  1                  7
# 41800406  Golden State Warriors       4                  4                 50
#
#                  Action Type       Shot Type  ...  Shot Zone Range  \
# ...

# %%
# replace score string to numbers
import re

# replace_all_these = {'low' : 1, 'med' : 2, 'high' : 3, 'vhigh' : 4 }; 
# df['col'] = df['col'].replace(replace_all_these)

# shots_type_replace = {'2PT Field Goal':2, '3PT Field Goal':3};
# nba_historical['Shot Type'] = nba_historical['Shot Type'].replace(shots_type_replace)


# df['Maintanance_price'].replace(to_replace = ['low', 'med','high','vhigh'], value =[1,2,3,4], inplace=True)
# df.head()

nba_historical['Shot Type'].replace(to_replace = ['2PT Field Goal', '3PT Field Goal'], value = [2,3], inplace=True)
nba_historical.head()
# Out:
#           Game Event ID  Player ID Player Name     Team ID  \
# Game ID
# 29700427            389        100  Tim Legler  1610612764
# 29700427            406        100  Tim Legler  1610612764
# 29700427            475        100  Tim Legler  1610612764
# 29700427            487        100  Tim Legler  1610612764
# 29700427            497        100  Tim Legler  1610612764
#
#                    Team Name  Period  Minutes Remaining  Seconds Remaining  \
# Game ID
# 29700427  Washington Wizards       4                 11                 22
# 29700427  Washington Wizards       4                  9                 36
# 29700427  Washington Wizards       4                  3                  7
# 29700427  Washington Wizards       4                  1                 45
# 29700427  Washington Wizards       4                  0                 45
#
#          Action Type  Shot Type  ...  Shot Zone Range Shot Distance  \
# Game ID                          ...
# ...

# %% [markdown]
# ## Create a new dataset filtered by 2014-15 season only

# %%
# filter data to get 2014-2015 season stats
#nba_filtered = nba_historical.loc[nba_historical['Game Date']>20140701]
nba_filtered_14_15 = nba_historical.loc[(nba_historical['Game Date']>20140701) & (nba_historical['Game Date']<20150416)]
#print(nba_filtered.shape)
print(nba_filtered_14_15.shape)
nba_filtered_14_15.head()
# Out:
# (205550, 22)
#           Game Event ID  Player ID   Player Name     Team ID  \
# Game ID
# 21400014             44     101106  Andrew Bogut  1610612744
# 21400014            336     101106  Andrew Bogut  1610612744
# 21400038              2     101106  Andrew Bogut  1610612744
# 21400038             25     101106  Andrew Bogut  1610612744
# 21400038             53     101106  Andrew Bogut  1610612744
#
#                       Team Name  Period  Minutes Remaining  Seconds Remaining  \
# Game ID
# 21400014  Golden State Warriors       1                  8                 11
# 21400014  Golden State Warriors       3                 11                 40
# 21400038  Golden State Warriors       1                 11                 45
# 21400038  Golden State Warriors       1                  8                  4
# 21400038  Golden State Warriors       1                  5                 52
#
#                      Action Type  Shot Type  ...  Shot Zone Range  \
# ...

# %%
#save to excel file
#nba_filtered_14_15.to_csv('nba_location_stats_2014-15.csv')

# %% [markdown]
# # Connect Pandas and SQL

# %%
# Import Modules and Create the Database Engine
from sqlalchemy import create_engine
import psycopg2
from config import db_password

db_string = f"postgres://postgres:{db_password}@localhost/NBA_DB"

# %%
# Create the database engine 
engine = create_engine(db_string)

# %%
#import 1st file - shot_logs
shot_log.to_sql(name="1_nba_shot_logs", con=engine,  if_exists='replace')

# %%
#import 2nd file - filtered nba with locations
nba_filtered_14_15.to_sql(name="2_nba_location_data", con=engine,  if_exists='replace')

# %%
#import 3rd file - stats
stats.to_sql(name="3_nba_stats", con=engine,  if_exists='replace')

# %% [markdown]
# Check datasets and connection with the stored in pgAdmin data.
# SQL queies in pgAdmin ran successfully.

# %%
# check 1st dataset (count by index)
shot_log_check = pd.read_sql_query('select COUNT(*) FROM "1_nba_shot_logs"',con=engine)
shot_log_check
# Out:
#     count
# 0  128069

# %%
#check 2nd dataset
nba_filtered_14_15_check = pd.read_sql_query('select COUNT(*) FROM "2_nba_location_data"', con=engine)
nba_filtered_14_15_check
# Out:
#     count
# 0  205550

# %%
#check 3rd 
stats_check = pd.read_sql_query('select COUNT(*) FROM "3_nba_stats"', con=engine)
stats_check
# Out:
#    count
# 0    490
